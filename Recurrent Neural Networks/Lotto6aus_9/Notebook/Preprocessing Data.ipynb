# %%
import pandas as pd

# Define file path
file_path = "/Users/kanha/Machine Learning/Recurrent Neural Networks/Lotto6aus_9/LOTTO_ab_2018/LOTTO_ab_2018.csv"

# Read CSV with the first row as the header
df = pd.read_csv(file_path,  encoding="latin-1", sep=";")

df
# Out:
#                                                          Datum       \
# 03.01.2018                          45  10  34  31          15   35
# 06.01.2018                          37  47  46  32           5   14
# 10.01.2018                          24  25   3  45          22   43
# 13.01.2018                          14  31  48   6           5   16
# 17.01.2018                          32  48  13   3          27   25
# ...                                                        ...  ...
# 26.02.2025                          12  45  24  29          22   17
# 01.03.2025                          25  36  26  11          44   30
# 05.03.2025                          46  22  45  26           4   29
# Spieleinsätze und Quoten in EUR NaN NaN NaN NaN NaN        NaN  NaN
# Alle Angaben ohne Gewähr        NaN NaN NaN NaN NaN        NaN  NaN
#
#                                                             Gewinnzahlen   ZZ  \
# ...

# %%
# Drop rows where all values are NaN (empty rows)
#df.dropna(how='all', inplace=True)

# Keep only rows where the number of columns matches the header
df = df[df.apply(lambda x: x.count(), axis=1) == len(df.columns)]

# Reset index after filtering
#df.reset_index(drop=True, inplace=True)

# Display cleaned data
df
#print(df.head())
# Out:
#                              Datum             Gewinnzahlen  ZZ  S  Spiel77  \
# 03.01.2018  45 10 34 31         15  35                   --  --  8  8977180
# 06.01.2018  37 47 46 32          5  14                   --  --  0  7434352
# 10.01.2018  24 25  3 45         22  43                   --  --  6  2899471
# 13.01.2018  14 31 48  6          5  16                   --  --  0  8547998
# 17.01.2018  32 48 13  3         27  25                   --  --  2  7542686
# ...                            ...  ..                  ...  .. ..      ...
# 19.02.2025   8  4 28 44         25  10                   --  --  3  2626333
# 22.02.2025  34 28 26  6          8  12                   --  --  0  6365471
# 26.02.2025  12 45 24 29         22  17                   --  --  7  5917250
# 01.03.2025  25 36 26 11         44  30                   --  --  8  9314956
# 05.03.2025  46 22 45 26          4  29                   --  --  7  4291183
#
# ...

# %%
df
# Out:
#                              Datum             Gewinnzahlen  ZZ  S  Spiel77  \
# 03.01.2018  45 10 34 31         15  35                   --  --  8  8977180
# 06.01.2018  37 47 46 32          5  14                   --  --  0  7434352
# 10.01.2018  24 25  3 45         22  43                   --  --  6  2899471
# 13.01.2018  14 31 48  6          5  16                   --  --  0  8547998
# 17.01.2018  32 48 13  3         27  25                   --  --  2  7542686
# ...                            ...  ..                  ...  .. ..      ...
# 19.02.2025   8  4 28 44         25  10                   --  --  3  2626333
# 22.02.2025  34 28 26  6          8  12                   --  --  0  6365471
# 26.02.2025  12 45 24 29         22  17                   --  --  7  5917250
# 01.03.2025  25 36 26 11         44  30                   --  --  8  9314956
# 05.03.2025  46 22 45 26          4  29                   --  --  7  4291183
#
# ...

# %%
df.to_csv("/Users/kanha/Machine Learning/Recurrent Neural Networks/Lotto6aus_9/LOTTO_ab_2018/LOTTO_ab_2018_preprossed.csv")
